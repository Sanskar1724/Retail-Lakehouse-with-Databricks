# %% [markdown]
# ## Bronze Layer

# %% [markdown]
# ### Reading From CSV files

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_system/cust_info.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace.bronze.crm_cust_info")

# %% [markdown]
# ### load "cust_info.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_system/prd_info.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace.bronze.crm_prd_info")

# %% [markdown]
# ###load "sales_details.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_system/sales_details.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace.bronze.crm_sales_details")

# %% [markdown]
# ### load "CUST_AZ12.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_system/CUST_AZ12.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace.bronze.erp_cust_az12")

# %% [markdown]
# ### load "LOC_A101.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_system/LOC_A101.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace.bronze.erp_loc_a101")

# %% [markdown]
# ### load "PX_CAT_G1V2.csv"

# %%
df = spark.read.option("header", "true").option("inferSchema", "true").csv('/Volumes/workspace/bronze/source_system/PX_CAT_G1V2.csv', header=True)
df.write.mode("overwrite").saveAsTable("workspace.bronze.erp_px_cat_g1v2")
