# %% [markdown]
# ## Orchestration Logic
# This notebook programmatically runs all Silver transformation notebooks in sequence.
# It becomes the **single entry point** for the Silver layer in Databricks Jobs.

# %%
notebooks = [
    "./Customer Relationship Management(CRM)/silver_crm_cust_info",
    "./Customer Relationship Management(CRM)/silver_crm_prd_info",
    "./Customer Relationship Management(CRM)/silver_crm_sales_details",
    "./Enterprise Resource Planning (ERP)/silver_erp_cust_az12",
    "./Enterprise Resource Planning (ERP)/silver_erp_loc_a101",
    "./Enterprise Resource Planning (ERP)/silver_erp_px_cat_g1v2"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
